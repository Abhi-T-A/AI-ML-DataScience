# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/US_honey_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %% [markdown]
# EDA-Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Q1. Which state is having the highest honey production through out all these years.(represent it using a bar graph)?

# %%
highest_honey=df.groupby('state')['production'].sum().sort_values(ascending=False).reset_index()

# %%
highest_honey
# Out:
#             state  production
# 0     NorthDakota   513742000
# 1      California   423876000
# 2     SouthDakota   355726000
# 3         Florida   280934000
# 4         Montana   197173000
# 5       Minnesota   176581000
# 6           Texas   129441000
# 7        Michigan   101063000
# 8       Wisconsin    99909000
# 9           Idaho    87188000
# 10        NewYork    78444000
# 11       Nebraska    63655000
# 12      Louisiana    60568000
# 13        Georgia    57426000
# 14     Washington    53238000
# 15       Arkansas    51846000
# 16           Iowa    48607000
# 17        Wyoming    43921000
# 18         Oregon    43789000
# 19        Arizona    38844000
# 20       Colorado    32660000
# 21           Ohio    22485000
# 22   Pennsylvania    21370000
# 23    Mississippi    21235000
# 24           Utah    20369000
# 25       Missouri    17904000
# 26         Hawaii    15420000
# 27        Alabama    14467000
# 28         Kansas    14138000
# 29      NewMexico    10082000
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=highest_honey,x='production',y='state',palette='hsv')
plt.show()
# Out:
# /tmp/ipython-input-12-2085387330.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=highest_honey,x='production',y='state',palette='hsv')

# %% [markdown]
# North Dakota is the highest honey production state.

# %% [markdown]
# Q2. Which state is having the highest and lowest yield_per_colony?(represent it using bar graph).

# %%
yield_high_low=df.groupby('state')['yield_per_colony'].sum().sort_values(ascending=False).reset_index()

# %%
yield_high_low
# Out:
#             state  yield_per_colony
# 0          Hawaii              2802
# 1       Louisiana              2506
# 2     Mississippi              2341
# 3     NorthDakota              2266
# 4         Montana              2148
# 5         Florida              1956
# 6     SouthDakota              1950
# 7           Texas              1921
# 8       Wisconsin              1896
# 9        Arkansas              1886
# 10      Minnesota              1885
# 11           Ohio              1763
# 12       Michigan              1753
# 13        NewYork              1745
# 14       Nebraska              1729
# 15        Wyoming              1698
# 16        Vermont              1674
# 17           Iowa              1659
# 18        Alabama              1615
# 19        Indiana              1605
# 20         Kansas              1570
# 21       Illinois              1562
# 22       Colorado              1520
# 23      Tennessee              1497
# 24        Arizona              1490
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=yield_high_low,x='yield_per_colony',y='state',palette='hsv')
plt.show()
# Out:
# /tmp/ipython-input-15-2291358076.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yield_high_low,x='yield_per_colony',y='state',palette='hsv')

# %% [markdown]
# Hawaii is the highest and Maryland is the lowest yield per colony.

# %% [markdown]
# Q3. Which year witnesses the highest profit in honey Production?(represent it using bar graph).

# %%
profit_honey=df.groupby('year')['value_of_production'].sum().sort_values(ascending=False).reset_index()

# %%
profit_honey
# Out:
#     year  value_of_production
# 0   2014            384483000
# 1   2016            335285000
# 2   2018            330766000
# 3   2017            326198000
# 4   2015            322505000
# 5   2013            315118000
# 6   2021            314413000
# 7   2019            303438000
# 8   2020            301831000
# 9   2012            280725000
# 10  2010            278370000
# 11  2011            258688000
# 12  2003            254833000
# 13  2008            224113000
# 14  2002            220747000
# 15  2009            207602000
# 16  2004            199044000
# 17  1996            179774000
# 18  2006            159363000
# 19  2007            155867000
# 20  2005            155611000
# 21  1998            145998000
# 22  1997            145598000
# 23  1995            137324000
# 24  2000            131022000
# 25  2001            126261000
# 26  1999            124187000

# %%
sns.barplot(data=profit_honey,x='year',y='value_of_production',palette='hsv')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-23-2593755928.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=profit_honey,x='year',y='value_of_production',palette='hsv')

# %% [markdown]
# 2014

# %% [markdown]
# Q4. Which state was having the highest stock in 2020?represent it using bar graph

# %%
df1=df[df['year']==2020]
#df1.groupby('state')['stocks'].sum().sort_values(ascending=False).reset_index()
df1.sort_values(by='stocks',ascending=False)
# Out:
#       Unnamed: 0          state  colonies_number  yield_per_colony  \
# 1065        1065    SouthDakota           245000                61
# 1060        1060    NorthDakota           495000                78
# 1055        1055        Montana           110000                81
# 1038        1038     California           320000                43
# 1052        1052      Minnesota           108000                55
# 1051        1051       Michigan            95000                47
# 1046        1046           Iowa            35000                58
# 1067        1067          Texas           157000                57
# 1062        1062         Oregon            95000                29
# 1040        1040        Florida           192000                46
# 1073        1073      Wisconsin            45000                50
# 1058        1058        NewYork            58000                56
# 1071        1071     Washington            98000                37
# ...

# %%
sns.barplot(data=df1,x='state',y='stocks',palette='hsv')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-28-1384036166.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df1,x='state',y='stocks',palette='hsv')

# %% [markdown]
# South Dakota

# %% [markdown]
# Q5. Which state is having the highest average price in the 21 st century?

# %%
df1=df[df['year']>=2020]
avg_price=df1.groupby('state')['average_price'].mean().sort_values(ascending=False).reset_index()

# %%
avg_price
# Out:
#             state  average_price
# 0        Virginia          7.130
# 1   NorthCarolina          6.170
# 2         Alabama          5.755
# 3        Illinois          5.740
# 4        Kentucky          5.180
# 5       Tennessee          4.615
# 6   SouthCarolina          4.380
# 7    WestVirginia          4.305
# 8         Indiana          3.900
# 9       NewJersey          3.795
# 10       Missouri          3.790
# 11   Pennsylvania          3.760
# 12        NewYork          3.640
# 13        Vermont          3.610
# 14           Ohio          3.600
# 15          Maine          3.270
# 16         Kansas          2.995
# 17      Wisconsin          2.960
# 18       Michigan          2.960
# 19        Georgia          2.625
# 20       Colorado          2.585
# 21     Washington          2.515
# 22           Iowa          2.500
# 23      Louisiana          2.480
# 24    Mississippi          2.380
# 25        Arizona          2.360
# 26        Florida          2.330
# ...

# %%
sns.barplot(data=avg_price,x='state',y='average_price',palette='hsv')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-32-1168158539.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_price,x='state',y='average_price',palette='hsv')

# %% [markdown]
# Virginia
