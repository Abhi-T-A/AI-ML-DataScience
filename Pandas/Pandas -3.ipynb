# %%
import pandas as pd
df1 = pd.read_csv('Auto.csv')
df1.head() # by default top 5 observations/records in data
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
df1.head(10)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
# 5   NaN        8.0           NaN         198    4341          10.0    70
# 6   NaN        8.0           NaN         220    4354           9.0    70
# 7  14.0        8.0           NaN         215    4312           8.5    70
# 8  14.0        8.0         455.0         225    4425          10.0    70
# 9  15.0        8.0         390.0         190    3850           8.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# ...

# %%
df1.tail() # bottom 5 observations
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin             name
# 392       1  ford mustang gl
# 393       2        vw pickup
# 394       1    dodge rampage
# 395       1      ford ranger
# 396       1       chevy s-10

# %%
df1.tail(2)
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin         name
# 395       1  ford ranger
# 396       1   chevy s-10

# %%
df1.tail(8)
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 389  32.0        4.0         144.0          96    2665          13.9    82
# 390  36.0        4.0         135.0          84    2370          13.0    82
# 391  27.0        4.0         151.0          90    2950          17.3    82
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin               name
# 389       3   toyota celica gt
# 390       1  dodge charger 2.2
# 391       1   chevrolet camaro
# 392       1    ford mustang gl
# 393       2          vw pickup
# 394       1      dodge rampage
# 395       1        ford ranger
# 396       1         chevy s-10

# %%
df1.shape # no.of rows * columns
# Out:
# (397, 9)

# %%
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
df1.dtypes # it will returns data types of columns # Horse power should be interger --> object
# numbers: int/float 
# strings: objects
# Out:
# mpg             float64
# cylinders       float64
# displacement    float64
# Horse Power      object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df1.isnull().sum() # it will add no.of times True appeared in each column
# Out:
# mpg             5
# cylinders       3
# displacement    5
# Horse Power     0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
df1.columns # column names are extracted in a list format
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'Horse Power', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     394 non-null    float64
#  2   displacement  392 non-null    float64
#  3   Horse Power   397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.0+ KB

# %%
df1.describe() # it will work on int/float data types
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  392.000000  394.000000    392.000000   397.000000    397.000000
# mean    23.611735    5.439086    191.080357  2970.261965     15.555668
# std      7.827466    1.693452    102.452019   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    100.750000  2223.000000     13.800000
# 50%     23.000000    4.000000    145.500000  2800.000000     15.500000
# 75%     29.000000    8.000000    260.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# [] --> list/ take subset 
# () --> tuple/ method(function)
# {} --> dict , sets

# %%
df1['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 392    27.0
# 393    44.0
# 394    32.0
# 395    28.0
# 396    31.0
# Name: mpg, Length: 397, dtype: float64

# %%
df1[['mpg','displacement','weight']] # outer square brackets --> to take subset in df1 and inner brackets are for multiple values
# Out:
#       mpg  displacement  weight
# 0    18.0         307.0    3504
# 1    15.0         350.0    3693
# 2     NaN         318.0    3436
# 3     NaN           NaN    3433
# 4     NaN           NaN    3449
# ..    ...           ...     ...
# 392  27.0         140.0    2790
# 393  44.0          97.0    2130
# 394  32.0         135.0    2295
# 395  28.0         120.0    2625
# 396  31.0         119.0    2720
#
# [397 rows x 3 columns]

# %%
df1['mpg'].mean()
# Out:
# 23.611734693877548

# %%
df1['mpg'].min()
# Out:
# 9.0

# %%
df1['mpg'].max()
# Out:
# 46.6

# %%
df1[['mpg','displacement','weight']].max()
# Out:
# mpg               46.6
# displacement     455.0
# weight          5140.0
# dtype: float64

# %%
#### How to create new columns in dataset

# %%
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
# price , quantity --> sales

# %%
df1['new_col1'] =  df1['acceleration'] + df1['origin'] # +, - , *, /,//,%, **
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name  new_col1
# 0       1  chevrolet chevelle malibu      13.0
# 1       1          buick skylark 320      12.5

# %%
df1['new_col2'] =  df1['acceleration'] ** 2
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name  new_col1  new_col2
# 0       1  chevrolet chevelle malibu      13.0    144.00
# 1       1          buick skylark 320      12.5    132.25

# %%
df1['new_col3'] = 20
df1.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name  new_col1  new_col2  new_col3
# 0       1  chevrolet chevelle malibu      13.0    144.00        20
# 1       1          buick skylark 320      12.5    132.25        20
# 2       1         plymouth satellite      12.0    121.00        20
# 3       1              amc rebel sst      13.0    144.00        20
# 4       1                ford torino      11.5    110.25        20

# %%
df1['new_col1'] = df1['acceleration'] +3 # if you give same column name it will overrides/replaced it , 
                                        # if its a new column name then it will create it
df1.head(3)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
#
#    origin                       name  new_col1  new_col2  new_col3
# 0       1  chevrolet chevelle malibu      15.0    144.00        20
# 1       1          buick skylark 320      14.5    132.25        20
# 2       1         plymouth satellite      14.0    121.00        20

# %%
#### Cleaning the dataset

# %%
# 1. Horse power data type issue 
# 2. Null values in columns

# %%
# data type conversions 
# int --> float / float --> int (astype)

# %%
df1['col4'] =  df1['acceleration'].astype(int)
df1.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name  new_col1  new_col2  new_col3  col4
# 0       1  chevrolet chevelle malibu      15.0    144.00        20    12
# 1       1          buick skylark 320      14.5    132.25        20    11

# %%
df1['Horse Power'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df1['Horse Power'].astype(int)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
df1['Horse Power'].isnull().sum()
# 0 indicates there are no null values available
# Out:
# 0

# %%
df1['Horse Power'] = pd.to_numeric(df1['Horse Power'], errors = 'coerce' )
df1['Horse Power'].isnull().sum()
# coerce method we are forcing pandas to do the conversion and if the conversion is not possible replace them with Null 
# wherever data type conversion is not possible we remove that string (creating blank/empty/null value)
# Out:
# 5

# %%
df1['Horse Power'].dtype
# Out:
# dtype('float64')

# %%
# Treating missing values

# %%
df1.head(10)
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
# 2   NaN        8.0         318.0        150.0    3436          11.0    70
# 3   NaN        8.0           NaN        150.0    3433          12.0    70
# 4   NaN        8.0           NaN        140.0    3449          10.5    70
# 5   NaN        8.0           NaN        198.0    4341          10.0    70
# 6   NaN        8.0           NaN        220.0    4354           9.0    70
# 7  14.0        8.0           NaN        215.0    4312           8.5    70
# 8  14.0        8.0         455.0        225.0    4425          10.0    70
# 9  15.0        8.0         390.0        190.0    3850           8.5    70
#
#    origin                       name  new_col1  new_col2  new_col3  col4
# 0       1  chevrolet chevelle malibu      15.0    144.00        20    12
# ...

# %%
df2 = df1.dropna()
df2.shape
# Out:
# (383, 13)

# %%
# df1 = df1.dropna()
# df1.dropna(inplace = True) # commit changes

# %%
# how to replace blank values # mean / median / mode / ML algorithm to predict missing values

df1['mpg'].mean() # average : sum/total
# Out:
# 23.611734693877548

# %%
df1['mpg'] = df1['mpg'].fillna(23.611) # fill na(null) values with 23.61 
# df1['mpg'] = df1['mpg'].fillna(df1['mpg'].mean())
df1.head(6)
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.000        8.0         307.0        130.0    3504          12.0    70
# 1  15.000        8.0         350.0        165.0    3693          11.5    70
# 2  23.611        8.0         318.0        150.0    3436          11.0    70
# 3  23.611        8.0           NaN        150.0    3433          12.0    70
# 4  23.611        8.0           NaN        140.0    3449          10.5    70
# 5  23.611        8.0           NaN        198.0    4341          10.0    70
#
#    origin                       name  new_col1  new_col2  new_col3  col4
# 0       1  chevrolet chevelle malibu      15.0    144.00        20    12
# 1       1          buick skylark 320      14.5    132.25        20    11
# 2       1         plymouth satellite      14.0    121.00        20    11
# 3       1              amc rebel sst      15.0    144.00        20    12
# ...

# %%
# how to remove unwanted columns
df1.drop('new_col1', axis = 1, inplace = True)
# axis = 1 --> to look for new_col1 in column names and remove that column --> inplace = True (commit your changes/ save the changes to df1)

# %%
df1.head(2)
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
#
#    origin                       name  new_col2  new_col3  col4
# 0       1  chevrolet chevelle malibu    144.00        20    12
# 1       1          buick skylark 320    132.25        20    11

# %%
df1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'Horse Power', 'weight',
#        'acceleration', 'year', 'origin', 'name', 'new_col2', 'new_col3',
#        'col4'],
#       dtype='object')

# %%
df1.drop(['new_col2', 'new_col3','col4'], axis = 1, inplace = True)
df1.head(2)
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
# how to rename column in dataset
df1.rename({'Horse Power': 'horse_power'}, axis =1 , inplace = True)
df1.head(2)
# Out:
#     mpg  cylinders  displacement  horse_power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
# Key Error: 
# 1. Spelling mistake 
# 2. Case sensitive 
# 3. column doesnt exist

# %%
df1.rename({0: 'horse_power'}, inplace = True) # by default axis will be set to 0 
df1.head(2)
# Out:
#               mpg  cylinders  displacement  horse_power  weight  acceleration  \
# horse_power  18.0        8.0         307.0        130.0    3504          12.0
# 1            15.0        8.0         350.0        165.0    3693          11.5
#
#              year  origin                       name
# horse_power    70       1  chevrolet chevelle malibu
# 1              70       1          buick skylark 320

# %%
df1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horse_power', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')
